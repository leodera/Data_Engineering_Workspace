# %%
import os
import time
import subprocess
from IPython.display import IFrame

# %%
app_code = """
import pandas as pd
import plotly.express as px
import streamlit as st

st.set_page_config(page_title="Streamlit in Jupyter", layout="wide")

st.title("Interactive Streamlit Dashboard")
st.write("Running directly inside a Jupyter Notebook cell.")


@st.cache_data
def load_data():
    return px.data.gapminder()

df = load_data()


st.sidebar.header("Filter Controls")
continent = st.sidebar.selectbox("Select Continent", df["continent"].unique())
metric = st.sidebar.selectbox("Select Metric", ["lifeExp", "gdpPercap", "pop"])


filtered_df = df[df["continent"] == continent]


fig = px.line(
    filtered_df, 
    x="year", 
    y=metric, 
    color="country", 
    title=f"{metric} over time in {continent}",
    template="plotly_white"
)

st.plotly_chart(fig, use_container_width=True)
"""

# %%
with open("app.py", "w") as f:
    f.write(app_code.strip())


os.system("pkill -f 'streamlit run'")

process = subprocess.Popen(
    ["streamlit", "run", "app.py", "--server.port", "8501", "--server.headless", "true"],
    stdout=subprocess.DEVNULL,
    stderr=subprocess.DEVNULL
)


time.sleep(2)

# %%
IFrame(src="http://localhost:8501", width="100%", height=700)
# Out:
#         <iframe
#             width="100%"
#             height="700"
#             src="http://localhost:8501"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
import os
import getpass

# %%
pat = getpass.getpass("Enter your GitHub Personal Access Token: ")
username = "Leodera"
repo = "Data_Engineering_Workspace"

# %%
os.system("git add .")

os.system('git commit -m "Update workspace: add Streamlit dashboard and analysis files"')

# %%
remote_url = f"https://{username}:{pat}@github.com/{username}/{repo}.git"
os.system(f"git push {remote_url} main")

del pat

# %%
import os
from data_profiling import ProfileReport
import pandas as pd
from data_cleaner import run_pipeline

# %%
df = pd.read_csv("banking_synthetic_data.csv")

# %%
profile = ProfileReport(df, title="Profiling Report", explorative=True)
profile.to_file("report.html")
# Out:
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
df_clean = run_pipeline(df, clean_outliers=True)

# 3. View cleaned output
df_clean.head()
# Out:
# --- Starting Data Cleaning Pipeline ---
# Initial Shape: (500, 50)
# Final Shape: (142, 47)
# --- Pipeline Execution Complete ---
#    customer_id account_id       account_type account_open_date account_status  \
# 2   CUST100002  ACC900002  Recurring Deposit        2021-08-20         Active
# 8   CUST100008  ACC900008      Fixed Deposit        2024-08-21            nan
# 11  CUST100011  ACC900011           Checking        2020-09-09         Frozen
# 25  CUST100025  ACC900025            Savings        2021-08-02            nan
# 29  CUST100029  ACC900029      Fixed Deposit        2021-11-14       Inactive
#
#    gender   age        state   pincode customer_segment  ... risk_rating  \
# 2     nan  47.0  Maharashtra  777568.0           Retail  ...         Low
# 8       M  23.0  West Bengal  910004.0           Retail  ...         nan
# 11      F  28.0    Karnataka  713762.0        Corporate  ...   Very High
# 25      F  22.0   Tamil Nadu  744274.0              nan  ...      Medium
# ...

# %%
df_clean2 = run_pipeline(df_clean)
# Out:
# --- Starting Data Cleaning Pipeline ---
# Initial Shape: (142, 47)
# Final Shape: (142, 47)
# --- Pipeline Execution Complete ---

# %%
pro = ProfileReport(df_clean2, title="Profiling Report", explorative=True)
pro.to_file("clean_report.html")
# Out:
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]
